# %%
import spacy
import fullmetalalchemy as fa
import tinytable as tt

# %%
nlp = spacy.load('en_core_web_sm')

# %%
engine = fa.create.create_engine('sqlite:///data.db')
text_table = fa.features.get_table('text', engine)
print(fa.features.get_row_count(text_table))
print(fa.features.get_column_names(text_table))
entity_table = fa.features.get_table('entities', engine)
print(fa.features.get_row_count(entity_table))
print(fa.features.get_column_names(entity_table))
found_table = fa.features.get_table('found_entities', engine)
print(fa.features.get_row_count(found_table))
print(fa.features.get_column_names(found_table))
# Out:
# 47959
# ['id', 'text_id', 'text']
# 23303
# ['id', 'entity']
# 138783
# ['id', 'text_id', 'entity_id', 'label']

# %%
def insert_label(text_id: int, entity: str, label: str) -> None:
    # check if entity is in entity_table
    existing_entities = fa.select.select_records_by_primary_keys(entity_table, [{'entity': entity}])
    if existing_entities == []:
        # if not, insert into entity_table
        fa.insert.insert_records(entity_table, [{'entity': entity}])
        existing_entities = fa.select.select_records_by_primary_keys(entity_table, [{'entity': entity}])
    entity_id = existing_entities[0]['id']
    # add entity to found_entity table
    record = {'text_id': text_id, 'entity_id': entity_id, 'label': label}
    fa.insert.insert_records(found_table, [record, ])

# %%
for row in fa.select.select_records_all(text_table):
    text_id = row['id']
    doc = nlp(row['text'])
    for ent in doc.ents:
        insert_label(text_id, ent.text, ent.label_)

# %%
entities_table = tt.read_sqlite('data.db', 'entities')
entities_table.head(100)
# Out:
# +----+------+----------------------------+
# |    |   id | entity                     |
# +====+======+============================+
# |  0 |    1 | Thousands                  |
# +----+------+----------------------------+
# |  1 |    2 | London                     |
# +----+------+----------------------------+
# |  2 |    3 | Iraq                       |
# +----+------+----------------------------+
# |  3 |    4 | British                    |
# +----+------+----------------------------+
# |  4 |    5 | Iranian                    |
# +----+------+----------------------------+
# |  5 |    6 | Wednesday                  |
# +----+------+----------------------------+
# |  6 |    7 | IAEA                       |
# +----+------+----------------------------+
# |  7 |    8 | Saturday                   |
# +----+------+----------------------------+
# |  8 |    9 | Orakzai                    |
# +----+------+----------------------------+
# |  9 |   10 | Taliban                    |
# +----+------+----------------------------+
# | 10 |   11 | South Waziristan           |
# +----+------+----------------------------+
# | 11 |   12 | a tense hour               |
# +----+------+----------------------------+
# | 12 |   13 | U.N.                       |
# +----+------+----------------------------+
# | 13 |   14 | Jan Egeland                |
# +----+------+----------------------------+
# | 14 |   15 | Sunday                     |
# +----+------+----------------------------+
# | 15 |   16 | U.S.                       |
# +----+------+----------------------------+
# | 16 |   17 | Indonesian                 |
# +----+------+----------------------------+
# | 17 |   18 | Australian                 |
# +----+------+----------------------------+
# | 18 |   19 | Aceh                       |
# +----+------+----------------------------+
# | 19 |   20 | Egeland                    |
# +----+------+----------------------------+
# | 20 |   21 | 1.8 million                |
# +----+------+----------------------------+
# | 21 |   22 | Indonesia                  |
# +----+------+----------------------------+
# | 22 |   23 | Sri Lanka                  |
# +----+------+----------------------------+
# | 23 |   24 | Maldives                   |
# +----+------+----------------------------+
# | 24 |   25 | India                      |
# +----+------+----------------------------+
# | 25 |   26 | last week 's               |
# +----+------+----------------------------+
# | 26 |   27 | millions                   |
# +----+------+----------------------------+
# | 27 |   28 | Asia                       |
# +----+------+----------------------------+
# | 28 |   29 | Africa                     |
# +----+------+----------------------------+
# | 29 |   30 | Some 1,27,000              |
# +----+------+----------------------------+
# | 30 |   31 | Lebanese                   |
# +----+------+----------------------------+
# | 31 |   32 | Friday                     |
# +----+------+----------------------------+
# | 32 |   33 | Christian                  |
# +----+------+----------------------------+
# | 33 |   34 | Beirut                     |
# +----+------+----------------------------+
# | 34 |   35 | United Nations             |
# +----+------+----------------------------+
# | 35 |   36 | New York                   |
# +----+------+----------------------------+
# | 36 |   37 | Fouad Siniora              |
# +----+------+----------------------------+
# | 37 |   38 | One                        |
# +----+------+----------------------------+
# | 38 |   39 | more than 20               |
# +----+------+----------------------------+
# | 39 |   40 | late Friday                |
# +----+------+----------------------------+
# | 40 |   41 | Lebanon                    |
# +----+------+----------------------------+
# | 41 |   42 | February                   |
# +----+------+----------------------------+
# | 42 |   43 | Rafik Hariri               |
# +----+------+----------------------------+
# | 43 |   44 | 20                         |
# +----+------+----------------------------+
# | 44 |   45 | Syria                      |
# +----+------+----------------------------+
# | 45 |   46 | days                       |
# +----+------+----------------------------+
# | 46 |   47 | Detlev Mehlis              |
# +----+------+----------------------------+
# | 47 |   48 | Damascus                   |
# +----+------+----------------------------+
# | 48 |   49 | Syrian                     |
# +----+------+----------------------------+
# | 49 |   50 | Iceland                    |
# +----+------+----------------------------+
# | 50 |   51 | Israeli                    |
# +----+------+----------------------------+
# | 51 |   52 | Ariel Sharon               |
# +----+------+----------------------------+
# | 52 |   53 | Thursday                   |
# +----+------+----------------------------+
# | 53 |   54 | last month                 |
# +----+------+----------------------------+
# | 54 |   55 | Sharon                     |
# +----+------+----------------------------+
# | 55 |   56 | December 25                |
# +----+------+----------------------------+
# | 56 |   57 | one week                   |
# +----+------+----------------------------+
# | 57 |   58 | first                      |
# +----+------+----------------------------+
# | 58 |   59 | $ 10 million               |
# +----+------+----------------------------+
# | 59 |   60 | SpaceShipOne               |
# +----+------+----------------------------+
# | 60 |   61 | Burt Rutan                 |
# +----+------+----------------------------+
# | 61 |   62 | Missouri                   |
# +----+------+----------------------------+
# | 62 |   63 | two-week                   |
# +----+------+----------------------------+
# | 63 |   64 | at least 100 kilometers    |
# +----+------+----------------------------+
# | 64 |   65 | Earth                      |
# +----+------+----------------------------+
# | 65 |   66 | late September             |
# +----+------+----------------------------+
# | 66 |   67 | early October              |
# +----+------+----------------------------+
# | 67 |   68 | California                 |
# +----+------+----------------------------+
# | 68 |   69 | Three                      |
# +----+------+----------------------------+
# | 69 |   70 | krona                      |
# +----+------+----------------------------+
# | 70 |   71 | two                        |
# +----+------+----------------------------+
# | 71 |   72 | more than $ 20 million     |
# +----+------+----------------------------+
# | 72 |   73 | Paul Allen                 |
# +----+------+----------------------------+
# | 73 |   74 | the Microsoft Corporation  |
# +----+------+----------------------------+
# | 74 |   75 | North Korea                |
# +----+------+----------------------------+
# | 75 |   76 | typhoon                    |
# +----+------+----------------------------+
# | 76 |   77 | Wipha                      |
# +----+------+----------------------------+
# | 77 |   78 | 14,000                     |
# +----+------+----------------------------+
# | 78 |   79 | 1,09,000                   |
# +----+------+----------------------------+
# | 79 |   80 | Monday                     |
# +----+------+----------------------------+
# | 80 |   81 | 8,000                      |
# +----+------+----------------------------+
# | 81 |   82 | Pyongyang                  |
# +----+------+----------------------------+
# | 82 |   83 | Last month                 |
# +----+------+----------------------------+
# | 83 |   84 | 600                        |
# +----+------+----------------------------+
# | 84 |   85 | more than 1,00,000         |
# +----+------+----------------------------+
# | 85 |   86 | Sumatra                    |
# +----+------+----------------------------+
# | 86 |   87 | The U.S. Geological Survey |
# +----+------+----------------------------+
# | 87 |   88 | Tuesday                    |
# +----+------+----------------------------+
# | 88 |   89 | morning                    |
# +----+------+----------------------------+
# | 89 |   90 | 6.7                        |
# +----+------+----------------------------+
# | 90 |   91 | Nias                       |
# +----+------+----------------------------+
# | 91 |   92 | Geir Haarde                |
# +----+------+----------------------------+
# | 92 |   93 | late March                 |
# +----+------+----------------------------+
# | 93 |   94 | more than 900              |
# +----+------+----------------------------+
# | 94 |   95 | December 26                |
# +----+------+----------------------------+
# | 95 |   96 | some 1,76,000              |
# +----+------+----------------------------+
# | 96 |   97 | 1,28,000                   |
# +----+------+----------------------------+
# | 97 |   98 | Nearly 50,000              |
# +----+------+----------------------------+
# | 98 |   99 | Snoop Dogg                 |
# +----+------+----------------------------+
# | 99 |  100 | five                       |
# +----+------+----------------------------+

# %%
found_table = tt.read_sqlite('data.db', 'found_entities')
found_table.head(100)
# Out:
# +----+------+-----------+-------------+----------+
# |    |   id |   text_id |   entity_id | label    |
# +====+======+===========+=============+==========+
# |  0 |    1 |         0 |           1 | CARDINAL |
# +----+------+-----------+-------------+----------+
# |  1 |    2 |         0 |           2 | GPE      |
# +----+------+-----------+-------------+----------+
# |  2 |    3 |         0 |           3 | GPE      |
# +----+------+-----------+-------------+----------+
# |  3 |    4 |         0 |           4 | NORP     |
# +----+------+-----------+-------------+----------+
# |  4 |    5 |         1 |           5 | NORP     |
# +----+------+-----------+-------------+----------+
# |  5 |    6 |         1 |           6 | DATE     |
# +----+------+-----------+-------------+----------+
# |  6 |    7 |         1 |           7 | ORG      |
# +----+------+-----------+-------------+----------+
# |  7 |    8 |         2 |           8 | DATE     |
# +----+------+-----------+-------------+----------+
# |  8 |    9 |         2 |           9 | PERSON   |
# +----+------+-----------+-------------+----------+
# |  9 |   10 |         2 |          10 | ORG      |
# +----+------+-----------+-------------+----------+
# | 10 |   11 |         2 |          11 | GPE      |
# +----+------+-----------+-------------+----------+
# | 11 |   12 |         3 |          12 | TIME     |
# +----+------+-----------+-------------+----------+
# | 12 |   13 |         4 |          13 | ORG      |
# +----+------+-----------+-------------+----------+
# | 13 |   14 |         4 |          14 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 14 |   15 |         4 |          15 | DATE     |
# +----+------+-----------+-------------+----------+
# | 15 |   16 |         4 |          16 | GPE      |
# +----+------+-----------+-------------+----------+
# | 16 |   17 |         4 |          17 | NORP     |
# +----+------+-----------+-------------+----------+
# | 17 |   18 |         4 |          18 | NORP     |
# +----+------+-----------+-------------+----------+
# | 18 |   19 |         4 |          19 | GPE      |
# +----+------+-----------+-------------+----------+
# | 19 |   20 |         5 |          20 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 20 |   21 |         5 |          21 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 21 |   22 |         5 |          22 | GPE      |
# +----+------+-----------+-------------+----------+
# | 22 |   23 |         5 |          23 | GPE      |
# +----+------+-----------+-------------+----------+
# | 23 |   24 |         5 |          24 | GPE      |
# +----+------+-----------+-------------+----------+
# | 24 |   25 |         5 |          25 | GPE      |
# +----+------+-----------+-------------+----------+
# | 25 |   26 |         6 |          26 | DATE     |
# +----+------+-----------+-------------+----------+
# | 26 |   27 |         6 |          27 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 27 |   28 |         6 |          28 | LOC      |
# +----+------+-----------+-------------+----------+
# | 28 |   29 |         6 |          29 | LOC      |
# +----+------+-----------+-------------+----------+
# | 29 |   30 |         7 |          30 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 30 |   31 |         8 |          13 | ORG      |
# +----+------+-----------+-------------+----------+
# | 31 |   32 |         9 |          31 | NORP     |
# +----+------+-----------+-------------+----------+
# | 32 |   33 |         9 |          32 | DATE     |
# +----+------+-----------+-------------+----------+
# | 33 |   34 |         9 |          33 | NORP     |
# +----+------+-----------+-------------+----------+
# | 34 |   35 |         9 |          34 | GPE      |
# +----+------+-----------+-------------+----------+
# | 35 |   36 |        10 |          34 | GPE      |
# +----+------+-----------+-------------+----------+
# | 36 |   37 |        10 |          35 | ORG      |
# +----+------+-----------+-------------+----------+
# | 37 |   38 |        10 |          36 | GPE      |
# +----+------+-----------+-------------+----------+
# | 38 |   39 |        10 |          37 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 39 |   40 |        10 |          31 | NORP     |
# +----+------+-----------+-------------+----------+
# | 40 |   41 |        11 |          38 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 41 |   42 |        11 |          39 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 42 |   43 |        11 |          40 | DATE     |
# +----+------+-----------+-------------+----------+
# | 43 |   44 |        12 |          41 | GPE      |
# +----+------+-----------+-------------+----------+
# | 44 |   45 |        12 |          42 | DATE     |
# +----+------+-----------+-------------+----------+
# | 45 |   46 |        12 |          43 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 46 |   47 |        12 |          44 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 47 |   48 |        13 |          45 | GPE      |
# +----+------+-----------+-------------+----------+
# | 48 |   49 |        13 |          32 | DATE     |
# +----+------+-----------+-------------+----------+
# | 49 |   50 |        13 |          46 | DATE     |
# +----+------+-----------+-------------+----------+
# | 50 |   51 |        13 |          13 | ORG      |
# +----+------+-----------+-------------+----------+
# | 51 |   52 |        13 |          47 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 52 |   53 |        13 |          48 | GPE      |
# +----+------+-----------+-------------+----------+
# | 53 |   54 |        13 |          49 | NORP     |
# +----+------+-----------+-------------+----------+
# | 54 |   55 |        14 |          50 | GPE      |
# +----+------+-----------+-------------+----------+
# | 55 |   56 |        15 |          51 | NORP     |
# +----+------+-----------+-------------+----------+
# | 56 |   57 |        15 |          52 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 57 |   58 |        15 |          53 | DATE     |
# +----+------+-----------+-------------+----------+
# | 58 |   59 |        15 |          54 | DATE     |
# +----+------+-----------+-------------+----------+
# | 59 |   60 |        16 |          55 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 60 |   61 |        18 |          55 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 61 |   62 |        19 |          55 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 62 |   63 |        19 |          56 | DATE     |
# +----+------+-----------+-------------+----------+
# | 63 |   64 |        19 |          57 | DATE     |
# +----+------+-----------+-------------+----------+
# | 64 |   65 |        21 |          58 | ORDINAL  |
# +----+------+-----------+-------------+----------+
# | 65 |   66 |        21 |          59 | MONEY    |
# +----+------+-----------+-------------+----------+
# | 66 |   67 |        22 |          60 | ORG      |
# +----+------+-----------+-------------+----------+
# | 67 |   68 |        22 |          61 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 68 |   69 |        22 |           8 | DATE     |
# +----+------+-----------+-------------+----------+
# | 69 |   70 |        22 |          16 | GPE      |
# +----+------+-----------+-------------+----------+
# | 70 |   71 |        22 |          62 | GPE      |
# +----+------+-----------+-------------+----------+
# | 71 |   72 |        23 |          60 | ORG      |
# +----+------+-----------+-------------+----------+
# | 72 |   73 |        23 |          63 | DATE     |
# +----+------+-----------+-------------+----------+
# | 73 |   74 |        23 |          64 | QUANTITY |
# +----+------+-----------+-------------+----------+
# | 74 |   75 |        23 |          65 | LOC      |
# +----+------+-----------+-------------+----------+
# | 75 |   76 |        24 |          66 | DATE     |
# +----+------+-----------+-------------+----------+
# | 76 |   77 |        24 |          67 | DATE     |
# +----+------+-----------+-------------+----------+
# | 77 |   78 |        24 |          68 | GPE      |
# +----+------+-----------+-------------+----------+
# | 78 |   79 |        25 |          69 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 79 |   80 |        25 |          70 | GPE      |
# +----+------+-----------+-------------+----------+
# | 80 |   81 |        26 |          71 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 81 |   82 |        27 |          60 | ORG      |
# +----+------+-----------+-------------+----------+
# | 82 |   83 |        27 |          72 | MONEY    |
# +----+------+-----------+-------------+----------+
# | 83 |   84 |        27 |          73 | PERSON   |
# +----+------+-----------+-------------+----------+
# | 84 |   85 |        27 |          74 | ORG      |
# +----+------+-----------+-------------+----------+
# | 85 |   86 |        28 |          75 | GPE      |
# +----+------+-----------+-------------+----------+
# | 86 |   87 |        28 |          26 | DATE     |
# +----+------+-----------+-------------+----------+
# | 87 |   88 |        28 |          76 | TIME     |
# +----+------+-----------+-------------+----------+
# | 88 |   89 |        28 |          77 | ORG      |
# +----+------+-----------+-------------+----------+
# | 89 |   90 |        28 |          78 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 90 |   91 |        28 |          79 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 91 |   92 |        29 |          80 | DATE     |
# +----+------+-----------+-------------+----------+
# | 92 |   93 |        30 |          81 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 93 |   94 |        32 |          82 | GPE      |
# +----+------+-----------+-------------+----------+
# | 94 |   95 |        33 |          83 | DATE     |
# +----+------+-----------+-------------+----------+
# | 95 |   96 |        33 |          75 | GPE      |
# +----+------+-----------+-------------+----------+
# | 96 |   97 |        33 |          84 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 97 |   98 |        33 |          85 | CARDINAL |
# +----+------+-----------+-------------+----------+
# | 98 |   99 |        34 |          22 | GPE      |
# +----+------+-----------+-------------+----------+
# | 99 |  100 |        34 |          86 | NORP     |
# +----+------+-----------+-------------+----------+

# %%
entities_table.join(found_table, 'id', 'entity_id', ).head(100)
# Out:
# +----+------+-----------+-----------+----------+-------------+
# |    |   id | entity    |   text_id | label    |   entity_id |
# +====+======+===========+===========+==========+=============+
# |  0 |    1 | Thousands |         0 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  1 |    1 | Thousands |       212 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  2 |    1 | Thousands |       318 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  3 |    1 | Thousands |       419 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  4 |    1 | Thousands |       523 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  5 |    1 | Thousands |       623 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  6 |    1 | Thousands |      1282 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  7 |    1 | Thousands |      1320 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  8 |    1 | Thousands |      2278 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# |  9 |    1 | Thousands |      2559 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 10 |    1 | Thousands |      2707 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 11 |    1 | Thousands |      2725 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 12 |    1 | Thousands |      3433 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 13 |    1 | Thousands |      3690 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 14 |    1 | Thousands |      4400 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 15 |    1 | Thousands |      4482 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 16 |    1 | Thousands |      4842 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 17 |    1 | Thousands |      4972 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 18 |    1 | Thousands |      5153 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 19 |    1 | Thousands |      5344 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 20 |    1 | Thousands |      5848 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 21 |    1 | Thousands |      7924 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 22 |    1 | Thousands |      8095 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 23 |    1 | Thousands |      8382 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 24 |    1 | Thousands |      8699 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 25 |    1 | Thousands |      9424 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 26 |    1 | Thousands |     10312 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 27 |    1 | Thousands |     10518 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 28 |    1 | Thousands |     10800 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 29 |    1 | Thousands |     11020 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 30 |    1 | Thousands |     11067 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 31 |    1 | Thousands |     11089 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 32 |    1 | Thousands |     11252 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 33 |    1 | Thousands |     12670 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 34 |    1 | Thousands |     12672 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 35 |    1 | Thousands |     12692 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 36 |    1 | Thousands |     12762 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 37 |    1 | Thousands |     13057 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 38 |    1 | Thousands |     13398 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 39 |    1 | Thousands |     13597 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 40 |    1 | Thousands |     13965 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 41 |    1 | Thousands |     14351 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 42 |    1 | Thousands |     15507 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 43 |    1 | Thousands |     16045 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 44 |    1 | Thousands |     16087 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 45 |    1 | Thousands |     16729 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 46 |    1 | Thousands |     16956 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 47 |    1 | Thousands |     17084 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 48 |    1 | Thousands |     18219 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 49 |    1 | Thousands |     18417 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 50 |    1 | Thousands |     18634 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 51 |    1 | Thousands |     18880 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 52 |    1 | Thousands |     19009 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 53 |    1 | Thousands |     19842 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 54 |    1 | Thousands |     20831 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 55 |    1 | Thousands |     21035 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 56 |    1 | Thousands |     21060 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 57 |    1 | Thousands |     21853 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 58 |    1 | Thousands |     21871 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 59 |    1 | Thousands |     22403 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 60 |    1 | Thousands |     22762 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 61 |    1 | Thousands |     22782 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 62 |    1 | Thousands |     22881 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 63 |    1 | Thousands |     23094 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 64 |    1 | Thousands |     23875 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 65 |    1 | Thousands |     23880 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 66 |    1 | Thousands |     24411 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 67 |    1 | Thousands |     25198 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 68 |    1 | Thousands |     26178 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 69 |    1 | Thousands |     26380 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 70 |    1 | Thousands |     27023 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 71 |    1 | Thousands |     27072 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 72 |    1 | Thousands |     27646 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 73 |    1 | Thousands |     27825 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 74 |    1 | Thousands |     28925 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 75 |    1 | Thousands |     29838 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 76 |    1 | Thousands |     30531 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 77 |    1 | Thousands |     31074 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 78 |    1 | Thousands |     31369 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 79 |    1 | Thousands |     31548 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 80 |    1 | Thousands |     31978 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 81 |    1 | Thousands |     32919 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 82 |    1 | Thousands |     33003 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 83 |    1 | Thousands |     33238 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 84 |    1 | Thousands |     33311 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 85 |    1 | Thousands |     33380 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 86 |    1 | Thousands |     34518 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 87 |    1 | Thousands |     35223 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 88 |    1 | Thousands |     35835 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 89 |    1 | Thousands |     36315 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 90 |    1 | Thousands |     36500 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 91 |    1 | Thousands |     37498 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 92 |    1 | Thousands |     37745 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 93 |    1 | Thousands |     38284 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 94 |    1 | Thousands |     39100 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 95 |    1 | Thousands |     39207 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 96 |    1 | Thousands |     40056 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 97 |    1 | Thousands |     40646 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 98 |    1 | Thousands |     40869 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
# | 99 |    1 | Thousands |     40883 | CARDINAL |           1 |
# +----+------+-----------+-----------+----------+-------------+
